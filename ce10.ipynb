# %%
# Whenever making a plot, don't go crazy trying to create a plot from first principles. Just google and modify another plot.
# The syntax for matplotlib and related packages is insane and will drive you crazy.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import plotly
import pandas as pd

# %%
penguins = pd.read_csv('penguins.csv')

# %%
sns.histplot(data=penguins, x="bill_length_mm")
# Out:
# <Axes: xlabel='bill_length_mm', ylabel='Count'>
